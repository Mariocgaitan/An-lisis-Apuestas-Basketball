# %%
import sys
from pathlib import Path

# Obtener la ruta absoluta del proyecto basándose en la ubicación del notebook
PROJECT_ROOT = Path(__file__).resolve().parent.parent if '__file__' in globals() else Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

import pandas as pd
import numpy as np
from src.config import DATA_DIR, PROCESSED_DIR

# %%
csv_path = DATA_DIR / "external" / "NBAoddsData.csv"

# %%
df = pd.read_csv(csv_path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37104 entries, 0 to 37103
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               37104 non-null  object
#  1   season             37104 non-null  int64
#  2   team               37104 non-null  object
#  3   opponent           37104 non-null  object
#  4   score              37104 non-null  int64
#  5   opponentScore      37104 non-null  int64
#  6   moneyLine          37104 non-null  float64
#  7   opponentMoneyLine  37104 non-null  float64
#  8   total              37104 non-null  float64
#  9   spread             37104 non-null  float64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 2.8+ MB

# %%
df.team.unique()
# Out:
# array(['Utah', 'LA Lakers', 'Houston', 'San Antonio', 'Portland',
#        'Golden State', 'New Jersey', 'Dallas', 'Cleveland', 'Seattle',
#        'Washington', 'Orlando', 'Chicago', 'Sacramento', 'Milwaukee',
#        'Toronto', 'New Orleans', 'Memphis', 'Denver', 'Philadelphia',
#        'Indiana', 'Miami', 'Detroit', 'Phoenix', 'New York', 'Atlanta',
#        'Minnesota', 'LA Clippers', 'Charlotte', 'Boston', 'Oklahoma City',
#        'Brooklyn'], dtype=object)

# %%
df.opponent.unique()
# Out:
# array(['Golden State', 'Houston', 'LA Lakers', 'Portland', 'San Antonio',
#        'Utah', 'Chicago', 'Cleveland', 'Dallas', 'Denver', 'Indiana',
#        'Memphis', 'Milwaukee', 'New Jersey', 'New Orleans', 'Orlando',
#        'Philadelphia', 'Sacramento', 'Seattle', 'Toronto', 'Washington',
#        'Detroit', 'Miami', 'Phoenix', 'Atlanta', 'Boston', 'Charlotte',
#        'LA Clippers', 'Minnesota', 'New York', 'Oklahoma City',
#        'Brooklyn'], dtype=object)

# %%
df.moneyLine.unique()
# Out:
# array([ 1.000e+02,  1.900e+02, -2.300e+02, -1.400e+03,  9.000e+02,
#        -1.200e+02, -1.250e+02, -1.400e+02,  1.200e+02,  6.250e+02,
#        -2.500e+02, -2.950e+02,  1.050e+02,  4.250e+02,  2.450e+02,
#        -3.050e+02, -5.250e+02,  2.100e+02, -8.250e+02,  2.550e+02,
#         1.600e+02, -1.600e+02, -1.900e+02,  5.750e+02, -7.250e+02,
#         1.400e+02,  2.850e+02,  1.500e+02,  4.000e+02,  3.150e+02,
#        -1.700e+02,  2.350e+02, -4.350e+02, -2.750e+02, -3.750e+02,
#         1.550e+02,  2.750e+02, -5.000e+02,  3.650e+02, -3.250e+02,
#        -2.000e+03,  1.200e+03, -1.750e+02, -3.350e+02,  1.500e+03,
#        -5.500e+02,  7.000e+02, -2.200e+02,  1.800e+02,  1.300e+02,
#        -1.300e+02, -1.500e+02, -1.000e+03, -3.000e+03,  1.100e+02,
#        -3.500e+02,  1.850e+02,  2.900e+02,  2.500e+02, -1.050e+02,
#        -4.250e+02, -2.150e+02,  3.550e+02, -3.000e+02, -1.150e+02,
#         1.700e+02, -2.000e+02, -1.950e+02,  3.350e+02, -1.350e+02,
# ...
